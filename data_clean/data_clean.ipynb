# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/gym_churn_us.csv")
df.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Cambios para la limpieza del df
# -Cambio de nombres de las columnas para una mejor lectura
# -cambio de Month_to_end_contract   de float a int
# -Checar y eliminar duplicados necesarios

# %%
df.rename(columns=
          {"Near_Location" : "near_location",
           "Partner" : "partner" ,
           "Promo_friends" : "promo_friends",
           "Phone" : "phone",
           "Contract_period" : "contract_period" ,
           "Group_visits" : "group_visits",
           "Age" : "age",
           "Avg_additional_charges_total" : "avg_aditional_charges_total",
           "Month_to_end_contract" : "month_to_end_contract",
           "Lifetime" : "lifetime",
           "Avg_class_frequency_total" : "avg_class_freq_total",
           "Avg_class_frequency_current_month" : "avg_class_freq_current_month",
           "Churn" : "churn"
           }, inplace= True)

df
# Out:
#       gender  near_location  partner  promo_friends  phone  contract_period  \
# 0          1              1        1              1      0                6
# 1          0              1        0              0      1               12
# 2          0              1        1              0      1                1
# 3          0              1        1              1      1               12
# 4          1              1        1              1      1                1
# ...      ...            ...      ...            ...    ...              ...
# 3995       1              1        1              0      1               12
# 3996       0              1        0              0      1                1
# 3997       1              1        1              1      1               12
# 3998       0              1        1              1      1                6
# 3999       1              0        1              0      0               12
#
# ...

# %%
df ["month_to_end_contract"] = df["month_to_end_contract"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gender                        4000 non-null   int64
#  1   near_location                 4000 non-null   int64
#  2   partner                       4000 non-null   int64
#  3   promo_friends                 4000 non-null   int64
#  4   phone                         4000 non-null   int64
#  5   contract_period               4000 non-null   int64
#  6   group_visits                  4000 non-null   int64
#  7   age                           4000 non-null   int64
#  8   avg_aditional_charges_total   4000 non-null   float64
#  9   month_to_end_contract         4000 non-null   int64
#  10  lifetime                      4000 non-null   int64
#  11  avg_class_freq_total          4000 non-null   float64
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#       gender  near_location  partner  promo_friends  phone  contract_period  \
# 0          1              1        1              1      0                6
# 1          0              1        0              0      1               12
# 2          0              1        1              0      1                1
# 3          0              1        1              1      1               12
# 4          1              1        1              1      1                1
# ...      ...            ...      ...            ...    ...              ...
# 3995       1              1        1              0      1               12
# 3996       0              1        0              0      1                1
# 3997       1              1        1              1      1               12
# 3998       0              1        1              1      1                6
# 3999       1              0        1              0      0               12
#
# ...

# %%
df.to_csv("../analisis/gym_churn_clean.csv", index=False)
df
# Out:
#       gender  near_location  partner  promo_friends  phone  contract_period  \
# 0          1              1        1              1      0                6
# 1          0              1        0              0      1               12
# 2          0              1        1              0      1                1
# 3          0              1        1              1      1               12
# 4          1              1        1              1      1                1
# ...      ...            ...      ...            ...    ...              ...
# 3995       1              1        1              0      1               12
# 3996       0              1        0              0      1                1
# 3997       1              1        1              1      1               12
# 3998       0              1        1              1      1                6
# 3999       1              0        1              0      0               12
#
# ...
